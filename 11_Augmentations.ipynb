# %% [markdown]
# <a href="https://colab.research.google.com/github/a-forty-two/cylons/blob/master/11_Augmentations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# a000001.png  sample_data

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('a000001.png')
img = cv2.resize(img, (200,200))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F79D3BEC908>

# %%
from keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img

generator = ImageDataGenerator(rotation_range=40, shear_range=0.25, zoom_range=0.25,
                               horizontal_flip=True, brightness_range=(0.5, 1.5))
# brightness will be adjusted from 50% to 150% 
img = load_img('a000001.png') # if there was no COMPUTER vision work, avoid CV2 
# in production , if you just had to load images, no need of CV2 library! 
img = img_to_array(img)
img[1]
# Out:
# array([[252., 239.,   2.],
#        [252., 239.,   2.],
#        [252., 239.,   2.],
#        ...,
#        [252., 239.,   2.],
#        [252., 239.,   2.],
#        [252., 239.,   2.]], dtype=float32)
